# %%
import pandas as pd
data={
'Name ':['Anindita','Yun Bonghee','Ayaan'],
'Marks':[88,92,77],
"Subject":["IT","LAW","CSE"]
}
df=pd.DataFrame(data)
s=pd.Series(data)

print(df)
print(s)
# Out:
#          Name   Marks Subject
# 0     Anindita     88      IT
# 1  Yun Bonghee     92     LAW
# 2        Ayaan     77     CSE
# Name       [Anindita, Yun Bonghee, Ayaan]
# Marks                        [88, 92, 77]
# Subject                    [IT, LAW, CSE]
# dtype: object

# %%
df[['Name ','Subject']]
# Out:
#          Name  Subject
# 0     Anindita      IT
# 1  Yun Bonghee     LAW
# 2        Ayaan     CSE

# %%
print(df[df['Marks']>80])
# Out:
#          Name   Marks Subject
# 0     Anindita     88      IT
# 1  Yun Bonghee     92     LAW

# %%
print(df)
# Out:
#          Name   Marks Subject
# 0     Anindita     88      IT
# 1  Yun Bonghee     92     LAW
# 2        Ayaan     77     CSE

# %%
df=df.drop('Grades',axis=1,inplace=True)

# %%
df['Grades'] = df.apply(lambda row: 'A', axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df['Grades'] = df.apply(lambda row: 'A', axis=1)
#
# AttributeError: 'NoneType' object has no attribute 'apply'

# %%
print(df)
# Out:
#          Name   Marks Grades
# 0     Anindita     88      A
# 1  Yun Bonghee     92      A
# 2        Ayaan     77      A

# %%
def Grade(row):
    return 'A'

df['Grades'] = df.apply(Grade, axis=1)

# %%
 df.drop('Subject',axis=1,inplace=True)
