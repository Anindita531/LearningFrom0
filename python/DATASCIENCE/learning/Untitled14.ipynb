# %%
import pandas as pd

# %%
df=pd.read_csv('patients.csv')
print(df)
# Out:
#      Age Gender  BloodPressure  SugarLevel  RecoveryTime
# 0   25.0      M            120        90.0            10
# 1   30.0      F            110         NaN             8
# 2  150.0      F            130       100.0            12
# 3   40.0      M            120        95.0             7
# 4   35.0      M            110        85.0             5
# 5    NaN      F            115        88.0             6

# %%
#Fill missing SugarLevel with the mean value.
df.fillna(df['SugarLevel'].mean(),inplace=True)

# %%
print(df)
# Out:
#      Age Gender  BloodPressure  SugarLevel  RecoveryTime
# 0   25.0      M            120        90.0            10
# 1   30.0      F            110        91.6             8
# 2  150.0      F            130       100.0            12
# 3   40.0      M            120        95.0             7
# 4   35.0      M            110        85.0             5
# 5   91.6      F            115        88.0             6

# %%
#Remove unrealistic ages (>120 or <0).
df=df[(df['Age']<120) &(df['Age']!=0)]

# %%
print(df)
# Out:
#     Age Gender  BloodPressure  SugarLevel  RecoveryTime
# 0  25.0      M            120        90.0            10
# 1  30.0      F            110        91.6             8
# 3  40.0      M            120        95.0             7
# 4  35.0      M            110        85.0             5
# 5  91.6      F            115        88.0             6

# %%
Fill missing Age with median.
