# %%
import pandas as pd
df=pd.read_csv('Fake.csv')
print(df)
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# ...

# %%
df.isnull()
# Out:
#        title   text  subject   date
# 0      False  False    False  False
# 1      False  False    False  False
# 2      False  False    False  False
# 3      False  False    False  False
# 4      False  False    False  False
# ...      ...    ...      ...    ...
# 23476  False  False    False  False
# 23477  False  False    False  False
# 23478  False  False    False  False
# 23479  False  False    False  False
# 23480  False  False    False  False
#
# [23481 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
df_cleaned = df.dropna()
df_filled = df.fillna('Unknown')

# %%
# Load fake and true datasets
fake = pd.read_csv("Fake.csv")
true = pd.read_csv("True.csv")

print("Fake shape:", fake.shape)
print("True shape:", true.shape)
# Out:
# Fake shape: (23481, 4)
# True shape: (21417, 4)

# %%
fake["label"] = 0   # 0 → Fake
true["label"] = 1   # 1 → Real

# %%
print(fake)
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# ...

# %%
print(true)
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %%
# Merge datasets into one
df = pd.concat([fake, true], axis=0)

print("Combined shape:", df.shape)
print(df.head())
# Out:
# Combined shape: (44898, 5)
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
# Shuffle so fake and real news are mixed
df = df.sample(frac=1).reset_index(drop=True)

# %%
# Save as a single dataset
df.to_csv("news_dataset.csv", index=False)
print("✅ Merged dataset saved as news_dataset.csv")
# Out:
# ✅ Merged dataset saved as news_dataset.csv

# %%
# 1. Import Libraries
# -----------------------------
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# -----------------------------
# 2. Load Dataset
# -----------------------------
data = pd.read_csv("news_dataset.csv")   # your merged dataset
print("Dataset Shape:", data.shape)
print(data.head())

# -----------------------------
# 3. Data Preprocessing
# -----------------------------
# Drop missing values
data = data.dropna()

# Features and Labels
X = data['text']      # news content
y = data['label']     # 0 = Real, 1 = Fake

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# -----------------------------
# 4. TF-IDF Vectorization
# -----------------------------
vectorizer = TfidfVectorizer(stop_words='english', max_df=0.7)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# -----------------------------
# 5. Logistic Regression Model
# -----------------------------
model = LogisticRegression()
model.fit(X_train_tfidf, y_train)
# -----------------------------
# 6. Evaluation
# -----------------------------
y_pred = model.predict(X_test_tfidf)

print("\nModel Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Dataset Shape: (44898, 5)
#                                                title  \
# 0  Allies silent, jibes in China over U.S. carrie...
# 1   Richard Branson: Trump Came To Me Broke And V...
# 2  Demoralized and divided: inside Catalonia's po...
# 3  Trump not planning to invoke executive privile...
# 4  The Great Con: Has Political Correctness Margi...
#
#                                                 text       subject  \
# 0  BEIJING (Reuters) - America’s allies in Asia w...  politicsNews
# 1  We all know Trump is vindictive. If he wasn t,...          News
# 2  BARCELONA (Reuters) - With the Spanish governm...     worldnews
# 3  (Reuters) - U.S. President Donald Trump does n...  politicsNews
# 4   Charles Hugh Smith Of Two MindsSo when the pr...       US_News
#
#                 date  label
# 0    April 19, 2017       1
# 1   October 25, 2016      0
# 2  October 24, 2017       1
# 3      June 3, 2017       1
# 4  November 21, 2016      0
#
# ...

# %%
# -----------------------------
# 7. Test with Custom Input
# -----------------------------
def predict_news(news_text):
    vec = vectorizer.transform([news_text])
    pred = model.predict(vec)[0]
    return "Fake News 📰❌" if pred == 1 else "Real News 📰✅"

print("\nTest Example:")
print(predict_news("Breaking: Scientists discover a new planet beyond our solar system."))
print(predict_news("Donald Trump caught hiding aliens in Area 51 leaked document."))
print(predict_news("China attack to India."))
print(predict_news("India break the records."))
# Out:
# Test Example:
# Real News 📰✅
# Real News 📰✅
# Real News 📰✅
# Real News 📰✅

# %%
print(y.value_counts())
# Out:
# label
# 0    23481
# 1    21417
# Name: count, dtype: int64

# %%
from sklearn.utils import resample

df_fake = data[data['label'] == 1]
df_real = data[data['label'] == 0]

df_fake_upsampled = resample(df_fake, 
                             replace=True,     
                             n_samples=len(df_real), 
                             random_state=42)

data_balanced = pd.concat([df_real, df_fake_upsampled])

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=200, random_state=42)
model.fit(X_train_tfidf, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
vectorizer = TfidfVectorizer(stop_words='english', max_df=0.7, ngram_range=(1,2))

# %%
# improved_fake_news_detection.py

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.utils import resample

# -----------------------------
# 1. Load Dataset
# -----------------------------
data = pd.read_csv("news_dataset.csv")
data = data.dropna()

# -----------------------------
# 2. Balance Dataset
# -----------------------------
df_fake = data[data['label'] == 1]
df_real = data[data['label'] == 0]

# Upsample fake news to match real news count
df_fake_upsampled = resample(df_fake, 
                             replace=True,     
                             n_samples=len(df_real), 
                             random_state=42)

# Combine
data_balanced = pd.concat([df_real, df_fake_upsampled])
data_balanced = data_balanced.sample(frac=1).reset_index(drop=True)

X = data_balanced['text']
y = data_balanced['label']

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# -----------------------------
# 3. TF-IDF Vectorization
# -----------------------------
vectorizer = TfidfVectorizer(stop_words='english', max_df=0.7, ngram_range=(1,2))
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# -----------------------------
# 4. Model Training
# -----------------------------
model = PassiveAggressiveClassifier(max_iter=1000, random_state=42)
model.fit(X_train_tfidf, y_train)

# -----------------------------
# 5. Evaluation
# -----------------------------
y_pred = model.predict(X_test_tfidf)

print("\nModel Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# -----------------------------
# 6. Test Custom Inputs
# -----------------------------
def predict_news(news_text):
    vec = vectorizer.transform([news_text])
    pred = model.predict(vec)[0]
    return "Fake News 📰❌" if pred == 1 else "Real News 📰✅"

# Test examples
test_texts = [
    "Breaking: Scientists discover a new planet beyond our solar system.",
    "Donald Trump caught hiding aliens in Area 51 leaked document.",
    "China attack to India.",
    "India breaks world record in chess."
]

for txt in test_texts:
    print(txt, "->", predict_news(txt))
# Out:
# Model Accuracy: 0.9965932077078675
#
# Confusion Matrix:
#  [[4673   24]
#  [   8 4688]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      4697
#            1       0.99      1.00      1.00      4696
#
#     accuracy                           1.00      9393
#    macro avg       1.00      1.00      1.00      9393
# weighted avg       1.00      1.00      1.00      9393
#
# Breaking: Scientists discover a new planet beyond our solar system. -> Real News 📰✅
# Donald Trump caught hiding aliens in Area 51 leaked document. -> Real News 📰✅
# China attack to India. -> Real News 📰✅
# India breaks world record in chess. -> Real News 📰✅
