# %%
# Install Kaggle package (only once)
# !pip install kaggle

# %%
import os
import shutil

# Change the path if needed
kaggle_json_path = 'kaggle.json'  # Put kaggle.json in same folder as notebook

# Make sure .kaggle folder exists in home directory
home = os.path.expanduser("~")
kaggle_dir = os.path.join(home, '.kaggle')
os.makedirs(kaggle_dir, exist_ok=True)

# Move kaggle.json to ~/.kaggle/
shutil.move(kaggle_json_path, os.path.join(kaggle_dir, 'kaggle.json'))

# Set permissions (Linux/Mac)
os.chmod(os.path.join(kaggle_dir, 'kaggle.json'), 0o600)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\shutil.py:856, in move(src, dst, copy_function)
#     855 try:
# --> 856     os.rename(src, real_dst)
#     857 except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'kaggle.json' -> 'C:\\Users\\user\\.kaggle\\kaggle.json'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 13
#      10 os.makedirs(kaggle_dir, exist_ok=True)
#      12 # Move kaggle.json to ~/.kaggle/
# ---> 13 shutil.move(kaggle_json_path, os.path.join(kaggle_dir, 'kaggle.json'))
#      15 # Set permissions (Linux/Mac)
#      16 os.chmod(os.path.join(kaggle_dir, 'kaggle.json'), 0o600)
#
# ...
