# %%
# !pip install numpy 
import numpy as np

# %%
X=np.array([[1],[2],[3],[4],[5]])
print(X)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]

# %%
X=np.array([1,2,3,4,5])
print(X)
# Out:
# [1 2 3 4 5]

# %%
X=np.array([[1],[2],[3],[4],[5]])
print(type(X))
# Out:
# <class 'numpy.ndarray'>
